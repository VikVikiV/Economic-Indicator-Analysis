# %%
# Importing the necessary Library
import pandas as pd

# %%
# Importing the cleaned Country GDP dataset 
df_GDP = pd.read_csv("C:\\Users\\Sidne\\OneDrive\\Desktop\\Semester3-V2\\ListOfCountriesByGDP.csv")
# Importing the cleaned Country Population dataset 
df_POP = pd.read_csv("C:\\Users\\Sidne\\OneDrive\\Desktop\\Semester3-V2\\ListOfCountriesByPopulation.csv")
# Importing the cleaned Country Exports dataset 
df_EXP = pd.read_csv("C:\\Users\\Sidne\\OneDrive\\Desktop\\Semester3-V2\\ListOfCountryExports.csv")

# %%
# Displaying the first few rows
df_GDP.head()
# Out:
#   Country_Territory     Forecast   GDP_Year     Estimate GDP_Year.1  \
# 0             World  110047109.0       2024  105,435,540       2023
# 1     United States   29167779.0       2024   27,360,935       2023
# 2             China   18273357.0  [n 1]2024   17,794,782  [n 3]2023
# 3           Germany    4710032.0       2024    4,456,081       2023
# 4             Japan    4070094.0       2024    4,212,945       2023
#
#     Estimate.1 GDP_Year.2
# 0  100,834,796       2022
# 1   25,744,100       2022
# 2   17,963,170  [n 1]2022
# 3    4,076,923       2022
# 4    4,232,173       2022

# %%
# Displaying the first few rows
df_POP.head()
# Out:
#   Country_Territory  Population_2023 UNContinentialRegion
# 0             World       8091734930                    –
# 1             India       1438069596                 Asia
# 2          China[a]       1422584933                 Asia
# 3     United States        343477335             Americas
# 4         Indonesia        281190067                 Asia

# %%
# Displaying the first few rows
df_EXP.head()
# Out:
#   Country_Territory  Exports              Top_Export
# 0  China (mainland)  3511248  Broadcasting equipment
# 1     United States  3051824               Petroleum
# 2           Germany  2104251                    Cars
# 3    United Kingdom  1074781                    Gold
# 4            France  1051679    Packaged medications

# %%
# Inner Merging all 3 datasets
df_first_inner_merge = pd.merge(df_GDP, df_POP, on='Country_Territory', how='inner')
df_final_inner_merge = pd.merge(df_first_inner_merge, df_EXP, on='Country_Territory', how='inner')

# %%
# Display the merged Dataframe
df_final_inner_merge.head()
# Out:
#   Country_Territory    Forecast GDP_Year    Estimate GDP_Year.1  Estimate.1  \
# 0     United States  29167779.0     2024  27,360,935       2023  25,744,100
# 1           Germany   4710032.0     2024   4,456,081       2023   4,076,923
# 2             Japan   4070094.0     2024   4,212,945       2023   4,232,173
# 3             India   3889130.0     2024   3,549,919       2023   3,465,541
# 4    United Kingdom   3587545.0     2024   3,340,032       2023   3,089,072
#
#   GDP_Year.2  Population_2023 UNContinentialRegion  Exports Top_Export
# 0       2022        343477335             Americas  3051824  Petroleum
# 1       2022         84548231               Europe  2104251       Cars
# 2       2022        124370947                 Asia   920737       Cars
# 3       2022       1438069596                 Asia   773223  Petroleum
# 4       2022         68682962               Europe  1074781       Gold

# %%
# Rows and Columns in the Merged DataFrame
df_final_inner_merge.shape
# Out:
# (170, 11)

# %%
# Setting 'UNContinentialRegion' as the new index
df_final_inner_merge = df_final_inner_merge.set_index('UNContinentialRegion')
df_final_inner_merge
# Out:
#                      Country_Territory    Forecast GDP_Year    Estimate  \
# UNContinentialRegion
# Americas                 United States  29167779.0     2024  27,360,935
# Europe                         Germany   4710032.0     2024   4,456,081
# Asia                             Japan   4070094.0     2024   4,212,945
# Asia                             India   3889130.0     2024   3,549,919
# Europe                  United Kingdom   3587545.0     2024   3,340,032
# ...                                ...         ...      ...         ...
# Oceania                       Kiribati       311.0     2024         279
# Oceania                          Palau       308.0     2024         263
# Oceania               Marshall Islands       305.0     2024         284
# Oceania                          Nauru       161.0     2024         154
# Oceania                         Tuvalu        66.0     2024          62
#
#                      GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  \
# UNContinentialRegion
# Americas                   2023  25,744,100       2022        343477335
# Europe                     2023   4,076,923       2022         84548231
# Asia                       2023   4,232,173       2022        124370947
# Asia                       2023   3,465,541       2022       1438069596
# Europe                     2023   3,089,072       2022         68682962
# ...                         ...         ...        ...              ...
# Oceania                    2023         223       2022           132530
# Oceania                    2023         225       2022            17727
# Oceania                    2023         279       2022            38827
# Oceania                    2023         147       2022            11875
# Oceania                    2023          59       2022             9816
#
#                       Exports Top_Export
# UNContinentialRegion
# Americas              3051824  Petroleum
# Europe                2104251       Cars
# Asia                   920737       Cars
# Asia                   773223  Petroleum
# Europe                1074781       Gold
# ...                       ...        ...
# Oceania                    11       Fish
# Oceania                    12  Computers
# Oceania                   130      Boats
# Oceania                    31       Fish
# Oceania                     3      Boats
#
# [170 rows x 10 columns]

# %%
# Resetting the index back to the default index
df_final_inner_merge = df_final_inner_merge.reset_index()
df_final_inner_merge
# Out:
#     UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 0               Americas     United States  29167779.0     2024  27,360,935
# 1                 Europe           Germany   4710032.0     2024   4,456,081
# 2                   Asia             Japan   4070094.0     2024   4,212,945
# 3                   Asia             India   3889130.0     2024   3,549,919
# 4                 Europe    United Kingdom   3587545.0     2024   3,340,032
# ..                   ...               ...         ...      ...         ...
# 165              Oceania          Kiribati       311.0     2024         279
# 166              Oceania             Palau       308.0     2024         263
# 167              Oceania  Marshall Islands       305.0     2024         284
# 168              Oceania             Nauru       161.0     2024         154
# 169              Oceania            Tuvalu        66.0     2024          62
#
#     GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports Top_Export
# 0         2023  25,744,100       2022        343477335  3051824  Petroleum
# 1         2023   4,076,923       2022         84548231  2104251       Cars
# 2         2023   4,232,173       2022        124370947   920737       Cars
# 3         2023   3,465,541       2022       1438069596   773223  Petroleum
# 4         2023   3,089,072       2022         68682962  1074781       Gold
# ..         ...         ...        ...              ...      ...        ...
# 165       2023         223       2022           132530       11       Fish
# 166       2023         225       2022            17727       12  Computers
# 167       2023         279       2022            38827      130      Boats
# 168       2023         147       2022            11875       31       Fish
# 169       2023          59       2022             9816        3      Boats
#
# [170 rows x 11 columns]

# %%
# Top Exports by Fish Group
Top_Exports_Fish = df_final_inner_merge[df_final_inner_merge['Top_Export'] == 'Fish']
Top_Exports_Fish
# Out:
#     UNContinentialRegion Country_Territory  Forecast GDP_Year Estimate  \
# 116               Africa         Mauritius   16359.0     2024   14,397
# 131                 Asia          Maldives    7199.0     2024    6,600
# 145               Africa        Cape Verde    2718.0     2024    2,587
# 156             Americas           Grenada    1406.0     2024    1,320
# 157              Oceania           Vanuatu    1289.0     2024    1,126
# 164              Oceania        Micronesia     484.0     2024      460
# 165              Oceania          Kiribati     311.0     2024      279
# 168              Oceania             Nauru     161.0     2024      154
#
#     GDP_Year.1 Estimate.1 GDP_Year.2  Population_2023  Exports Top_Export
# 116       2023     12,898       2022          1273588     4918       Fish
# 131       2023      6,170       2022           525994     5096       Fish
# 145       2023      2,314       2022           522331      855       Fish
# 156       2023      1,192       2022           117081      394       Fish
# 157       2023        985       2022           320409       89       Fish
# 164       2023        427       2022           112630      126       Fish
# 165       2023        223       2022           132530       11       Fish
# 168       2023        147       2022            11875       31       Fish

# %%
# Exports by Cars & Region by Europe Group
Export_Cars_Region_Europe = df_final_inner_merge[(df_final_inner_merge['Top_Export'] == 'Cars') &
                                                (df_final_inner_merge['UNContinentialRegion'] == 'Europe')]
Export_Cars_Region_Europe
# Out:
#     UNContinentialRegion Country_Territory   Forecast GDP_Year   Estimate  \
# 1                 Europe           Germany  4710032.0     2024  4,456,081
# 17                Europe            Sweden   609039.0     2024    593,268
# 21                Europe           Austria   535804.0     2024    516,034
# 33                Europe           Romania   380561.0     2024    351,003
# 43                Europe           Hungary   228806.0     2024    212,389
# 50                Europe          Slovakia   142617.0     2024    132,794
# 140               Europe           Andorra     3897.0     2024      3,728
#
#     GDP_Year.1 Estimate.1 GDP_Year.2  Population_2023  Exports Top_Export
# 1         2023  4,076,923       2022         84548231  2104251       Cars
# 17        2023    591,188       2022         10551494   310493       Cars
# 21        2023    470,302       2022          9130429   268277       Cars
# 33        2023    300,690       2022         19118479   137345       Cars
# 43        2023    177,337       2022          9686463   161609       Cars
# 50        2023    115,304       2022          5518055   114157       Cars
# 140       2023      3,376       2022            80856     2414       Cars

# %%
df_final_inner_merge
# Out:
#     UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 0               Americas     United States  29167779.0     2024  27,360,935
# 1                 Europe           Germany   4710032.0     2024   4,456,081
# 2                   Asia             Japan   4070094.0     2024   4,212,945
# 3                   Asia             India   3889130.0     2024   3,549,919
# 4                 Europe    United Kingdom   3587545.0     2024   3,340,032
# ..                   ...               ...         ...      ...         ...
# 165              Oceania          Kiribati       311.0     2024         279
# 166              Oceania             Palau       308.0     2024         263
# 167              Oceania  Marshall Islands       305.0     2024         284
# 168              Oceania             Nauru       161.0     2024         154
# 169              Oceania            Tuvalu        66.0     2024          62
#
#     GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports Top_Export
# 0         2023  25,744,100       2022        343477335  3051824  Petroleum
# 1         2023   4,076,923       2022         84548231  2104251       Cars
# 2         2023   4,232,173       2022        124370947   920737       Cars
# 3         2023   3,465,541       2022       1438069596   773223  Petroleum
# 4         2023   3,089,072       2022         68682962  1074781       Gold
# ..         ...         ...        ...              ...      ...        ...
# 165       2023         223       2022           132530       11       Fish
# 166       2023         225       2022            17727       12  Computers
# 167       2023         279       2022            38827      130      Boats
# 168       2023         147       2022            11875       31       Fish
# 169       2023          59       2022             9816        3      Boats
#
# [170 rows x 11 columns]

# %%
# Sorting as decreasing order by Per_global_total
df_final_inner_merge = df_final_inner_merge.sort_values(by = 'Exports', ascending = False)
df_final_inner_merge
# Out:
#     UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 0               Americas     United States  29167779.0     2024  27,360,935
# 1                 Europe           Germany   4710032.0     2024   4,456,081
# 4                 Europe    United Kingdom   3587545.0     2024   3,340,032
# 2                   Asia             Japan   4070094.0     2024   4,212,945
# 5                 Europe             Italy   2376510.0     2024   2,254,851
# ..                   ...               ...         ...      ...         ...
# 163              Oceania             Tonga       581.0     2024         500
# 168              Oceania             Nauru       161.0     2024         154
# 166              Oceania             Palau       308.0     2024         263
# 165              Oceania          Kiribati       311.0     2024         279
# 169              Oceania            Tuvalu        66.0     2024          62
#
#     GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports  \
# 0         2023  25,744,100       2022        343477335  3051824
# 1         2023   4,076,923       2022         84548231  2104251
# 4         2023   3,089,072       2022         68682962  1074781
# 2         2023   4,232,173       2022        124370947   920737
# 5         2023   2,046,952       2022         59499453   793588
# ..         ...         ...        ...              ...      ...
# 163       2022         488       2022           104597       60
# 168       2023         147       2022            11875       31
# 166       2023         225       2022            17727       12
# 165       2023         223       2022           132530       11
# 169       2023          59       2022             9816        3
#
#                Top_Export
# 0               Petroleum
# 1                    Cars
# 4                    Gold
# 2                    Cars
# 5    Packaged medications
# ..                    ...
# 163             Shellfish
# 168                  Fish
# 166             Computers
# 165                  Fish
# 169                 Boats
#
# [170 rows x 11 columns]

# %%
# Sorting Exports in decreasing order 
df_final_inner_merge = df_final_inner_merge.sort_values(by = 'Exports', ascending = False)
df_final_inner_merge
# Out:
#     UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 0               Americas     United States  29167779.0     2024  27,360,935
# 1                 Europe           Germany   4710032.0     2024   4,456,081
# 4                 Europe    United Kingdom   3587545.0     2024   3,340,032
# 2                   Asia             Japan   4070094.0     2024   4,212,945
# 5                 Europe             Italy   2376510.0     2024   2,254,851
# ..                   ...               ...         ...      ...         ...
# 163              Oceania             Tonga       581.0     2024         500
# 168              Oceania             Nauru       161.0     2024         154
# 166              Oceania             Palau       308.0     2024         263
# 165              Oceania          Kiribati       311.0     2024         279
# 169              Oceania            Tuvalu        66.0     2024          62
#
#     GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports  \
# 0         2023  25,744,100       2022        343477335  3051824
# 1         2023   4,076,923       2022         84548231  2104251
# 4         2023   3,089,072       2022         68682962  1074781
# 2         2023   4,232,173       2022        124370947   920737
# 5         2023   2,046,952       2022         59499453   793588
# ..         ...         ...        ...              ...      ...
# 163       2022         488       2022           104597       60
# 168       2023         147       2022            11875       31
# 166       2023         225       2022            17727       12
# 165       2023         223       2022           132530       11
# 169       2023          59       2022             9816        3
#
#                Top_Export
# 0               Petroleum
# 1                    Cars
# 4                    Gold
# 2                    Cars
# 5    Packaged medications
# ..                    ...
# 163             Shellfish
# 168                  Fish
# 166             Computers
# 165                  Fish
# 169                 Boats
#
# [170 rows x 11 columns]

# %%
# Sorting Exports in increasing order 
df_final_inner_merge_sort = df_final_inner_merge.sort_values(by = 'Exports', ascending = True)
df_final_inner_merge_sort
# Out:
#     UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 169              Oceania            Tuvalu        66.0     2024          62
# 165              Oceania          Kiribati       311.0     2024         279
# 166              Oceania             Palau       308.0     2024         263
# 168              Oceania             Nauru       161.0     2024         154
# 163              Oceania             Tonga       581.0     2024         500
# ..                   ...               ...         ...      ...         ...
# 5                 Europe             Italy   2376510.0     2024   2,254,851
# 2                   Asia             Japan   4070094.0     2024   4,212,945
# 4                 Europe    United Kingdom   3587545.0     2024   3,340,032
# 1                 Europe           Germany   4710032.0     2024   4,456,081
# 0               Americas     United States  29167779.0     2024  27,360,935
#
#     GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports  \
# 169       2023          59       2022             9816        3
# 165       2023         223       2022           132530       11
# 166       2023         225       2022            17727       12
# 168       2023         147       2022            11875       31
# 163       2022         488       2022           104597       60
# ..         ...         ...        ...              ...      ...
# 5         2023   2,046,952       2022         59499453   793588
# 2         2023   4,232,173       2022        124370947   920737
# 4         2023   3,089,072       2022         68682962  1074781
# 1         2023   4,076,923       2022         84548231  2104251
# 0         2023  25,744,100       2022        343477335  3051824
#
#                Top_Export
# 169                 Boats
# 165                  Fish
# 166             Computers
# 168                  Fish
# 163             Shellfish
# ..                    ...
# 5    Packaged medications
# 2                    Cars
# 4                    Gold
# 1                    Cars
# 0               Petroleum
#
# [170 rows x 11 columns]

# %%
# Computing the Summary Statistics for the Inner Merged DataFrame 
Inner_Merged_Summary_Stats = df_final_inner_merge.describe()
print("Summary Statistics for the Inner Merged DataFrame:")
Inner_Merged_Summary_Stats
# Out:
# Summary Statistics for the Inner Merged DataFrame:
#            Forecast  Population_2023       Exports
# count  1.670000e+02     1.700000e+02  1.700000e+02
# mean   4.813553e+05     3.601044e+07  1.303653e+05
# std    2.352078e+06     1.199510e+08  3.428195e+05
# min    6.600000e+01     9.816000e+03  3.000000e+00
# 25%    1.097450e+04     1.856261e+06  2.790000e+03
# 50%    4.304400e+04     9.123054e+06  1.133450e+04
# 75%    2.524840e+05     3.088810e+07  7.217200e+04
# max    2.916778e+07     1.438070e+09  3.051824e+06

# %%
df_final_inner_merge
# Out:
#     UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 0               Americas     United States  29167779.0     2024  27,360,935
# 1                 Europe           Germany   4710032.0     2024   4,456,081
# 4                 Europe    United Kingdom   3587545.0     2024   3,340,032
# 2                   Asia             Japan   4070094.0     2024   4,212,945
# 5                 Europe             Italy   2376510.0     2024   2,254,851
# ..                   ...               ...         ...      ...         ...
# 163              Oceania             Tonga       581.0     2024         500
# 168              Oceania             Nauru       161.0     2024         154
# 166              Oceania             Palau       308.0     2024         263
# 165              Oceania          Kiribati       311.0     2024         279
# 169              Oceania            Tuvalu        66.0     2024          62
#
#     GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports  \
# 0         2023  25,744,100       2022        343477335  3051824
# 1         2023   4,076,923       2022         84548231  2104251
# 4         2023   3,089,072       2022         68682962  1074781
# 2         2023   4,232,173       2022        124370947   920737
# 5         2023   2,046,952       2022         59499453   793588
# ..         ...         ...        ...              ...      ...
# 163       2022         488       2022           104597       60
# 168       2023         147       2022            11875       31
# 166       2023         225       2022            17727       12
# 165       2023         223       2022           132530       11
# 169       2023          59       2022             9816        3
#
#                Top_Export
# 0               Petroleum
# 1                    Cars
# 4                    Gold
# 2                    Cars
# 5    Packaged medications
# ..                    ...
# 163             Shellfish
# 168                  Fish
# 166             Computers
# 165                  Fish
# 169                 Boats
#
# [170 rows x 11 columns]

# %%
# Slicing the data based on the column I am interested in
sliced_data = df_final_inner_merge.loc[1:9, ['Country_Territory', 'Forecast', 'Population_2023', 'Exports', 'Top_Export']]
sliced_data
# Out:
#    Country_Territory   Forecast  Population_2023  Exports  \
# 1            Germany  4710032.0         84548231  2104251
# 4     United Kingdom  3587545.0         68682962  1074781
# 2              Japan  4070094.0        124370947   920737
# 5              Italy  2376510.0         59499453   793588
# 22         Singapore   530708.0          5789090   778000
# 3              India  3889130.0       1438069596   773223
# 9        South Korea  1869916.0         51748739   769534
#
#               Top_Export
# 1                   Cars
# 4                   Gold
# 2                   Cars
# 5   Packaged medications
# 22   Integrated circuits
# 3              Petroleum
# 9    Integrated circuits

# %%
# Slicing the data by condition where Exports are greater than 500000
Exports_slice = sliced_data[sliced_data['Exports'] > 500000]
Exports_slice
# Out:
#    Country_Territory   Forecast  Population_2023  Exports  \
# 1            Germany  4710032.0         84548231  2104251
# 4     United Kingdom  3587545.0         68682962  1074781
# 2              Japan  4070094.0        124370947   920737
# 5              Italy  2376510.0         59499453   793588
# 22         Singapore   530708.0          5789090   778000
# 3              India  3889130.0       1438069596   773223
# 9        South Korea  1869916.0         51748739   769534
#
#               Top_Export
# 1                   Cars
# 4                   Gold
# 2                   Cars
# 5   Packaged medications
# 22   Integrated circuits
# 3              Petroleum
# 9    Integrated circuits

# %%
# Importing the Library necessary for transferring DataFrame to MongoDB
from pymongo import MongoClient
df_final_inner_merge.head()
# Out:
#   UNContinentialRegion Country_Territory    Forecast GDP_Year    Estimate  \
# 0             Americas     United States  29167779.0     2024  27,360,935
# 1               Europe           Germany   4710032.0     2024   4,456,081
# 4               Europe    United Kingdom   3587545.0     2024   3,340,032
# 2                 Asia             Japan   4070094.0     2024   4,212,945
# 5               Europe             Italy   2376510.0     2024   2,254,851
#
#   GDP_Year.1  Estimate.1 GDP_Year.2  Population_2023  Exports  \
# 0       2023  25,744,100       2022        343477335  3051824
# 1       2023   4,076,923       2022         84548231  2104251
# 4       2023   3,089,072       2022         68682962  1074781
# 2       2023   4,232,173       2022        124370947   920737
# 5       2023   2,046,952       2022         59499453   793588
#
#              Top_Export
# 0             Petroleum
# 1                  Cars
# 4                  Gold
# 2                  Cars
# 5  Packaged medications

# %%
# Converting the DataFrame to a Dictionary
new_final_inner_merge_dict = df_final_inner_merge.to_dict('records')

# %%
# Connecting to the local MongoDB
client = MongoClient("mongodb://localhost:27017/")

# %%
# Asigning the Database Name and the Collection of data
db = client['GDP_POP_EXP'] 
# Specifying the collections for the inner merged data
inner_merge_collection = db['inner_merged_data']

# %%
# Inserting the Data into MongoDB
inner_merge_collection.insert_many(new_final_inner_merge_dict)
print('Inner merged data Imported Successfully')
# Out:
# Inner merged data Imported Successfully

# %%
# Verifying the Inner merged data
print("Inner Merged Data from MongoDB:")
for document in inner_merge_collection.find():
    print(document)
# Out:
# Inner Merged Data from MongoDB:
# {'_id': ObjectId('6764ed542cdfb9c98fabec30'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'United States', 'Forecast': 29167779.0, 'GDP_Year': '2024', 'Estimate': '27,360,935', 'GDP_Year.1': '2023', 'Estimate.1': '25,744,100', 'GDP_Year.2': '2022', 'Population_2023': 343477335, 'Exports': 3051824, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec31'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Germany', 'Forecast': 4710032.0, 'GDP_Year': '2024', 'Estimate': '4,456,081', 'GDP_Year.1': '2023', 'Estimate.1': '4,076,923', 'GDP_Year.2': '2022', 'Population_2023': 84548231, 'Exports': 2104251, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec32'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'United Kingdom', 'Forecast': 3587545.0, 'GDP_Year': '2024', 'Estimate': '3,340,032', 'GDP_Year.1': '2023', 'Estimate.1': '3,089,072', 'GDP_Year.2': '2022', 'Population_2023': 68682962, 'Exports': 1074781, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec33'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Japan', 'Forecast': 4070094.0, 'GDP_Year': '2024', 'Estimate': '4,212,945', 'GDP_Year.1': '2023', 'Estimate.1': '4,232,173', 'GDP_Year.2': '2022', 'Population_2023': 124370947, 'Exports': 920737, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec34'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Italy', 'Forecast': 2376510.0, 'GDP_Year': '2024', 'Estimate': '2,254,851', 'GDP_Year.1': '2023', 'Estimate.1': '2,046,952', 'GDP_Year.2': '2022', 'Population_2023': 59499453, 'Exports': 793588, 'Top_Export': 'Packaged medications'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec35'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Singapore', 'Forecast': 530708.0, 'GDP_Year': '2024', 'Estimate': '501,428', 'GDP_Year.1': '2023', 'Estimate.1': '466,788', 'GDP_Year.2': '2022', 'Population_2023': 5789090, 'Exports': 778000, 'Top_Export': 'Integrated circuits'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec36'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'India', 'Forecast': 3889130.0, 'GDP_Year': '2024', 'Estimate': '3,549,919', 'GDP_Year.1': '2023', 'Estimate.1': '3,465,541', 'GDP_Year.2': '2022', 'Population_2023': 1438069596, 'Exports': 773223, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec37'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'South Korea', 'Forecast': 1869916.0, 'GDP_Year': '2024', 'Estimate': '1,712,793', 'GDP_Year.1': '2023', 'Estimate.1': '1,673,916', 'GDP_Year.2': '2022', 'Population_2023': 51748739, 'Exports': 769534, 'Top_Export': 'Integrated circuits'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec38'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'United Arab Emirates', 'Forecast': 545053.0, 'GDP_Year': '2024', 'Estimate': '504,173', 'GDP_Year.1': '2023', 'Estimate.1': '507,063', 'GDP_Year.2': '2022', 'Population_2023': 10642081, 'Exports': 753000, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec39'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Ireland', 'Forecast': 560566.0, 'GDP_Year': '2024', 'Estimate': '545,629', 'GDP_Year.1': '2023', 'Estimate.1': '532,415', 'GDP_Year.2': '2022', 'Population_2023': 5196630, 'Exports': 731813, 'Top_Export': 'ICT'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec3a'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Canada', 'Forecast': 2214796.0, 'GDP_Year': '2024', 'Estimate': '2,140,086', 'GDP_Year.1': '2023', 'Estimate.1': '2,137,939', 'GDP_Year.2': '2022', 'Population_2023': 39299105, 'Exports': 717677, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec3b'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Switzerland', 'Forecast': 942265.0, 'GDP_Year': '2024', 'Estimate': '884,940', 'GDP_Year.1': '2023', 'Estimate.1': '818,426', 'GDP_Year.2': '2022', 'Population_2023': 8870561, 'Exports': 661627, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec3c'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Mexico', 'Forecast': 1848125.0, 'GDP_Year': '2024', 'Estimate': '1,788,887', 'GDP_Year.1': '2023', 'Estimate.1': '1,463,323', 'GDP_Year.2': '2022', 'Population_2023': 129739759, 'Exports': 649312, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec3d'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Belgium', 'Forecast': 662183.0, 'GDP_Year': '2024', 'Estimate': '632,217', 'GDP_Year.1': '2023', 'Estimate.1': '582,643', 'GDP_Year.2': '2022', 'Population_2023': 11712893, 'Exports': 535173, 'Top_Export': 'Vaccines'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec3e'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Poland', 'Forecast': 862908.0, 'GDP_Year': '2024', 'Estimate': '811,229', 'GDP_Year.1': '2023', 'Estimate.1': '688,125', 'GDP_Year.2': '2022', 'Population_2023': 38762844, 'Exports': 469264, 'Top_Export': 'Car parts'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec3f'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Russia', 'Forecast': 2184316.0, 'GDP_Year': '2024', 'Estimate': '2,021,421', 'GDP_Year.1': '2023', 'Estimate.1': '2,240,422', 'GDP_Year.2': '2022', 'Population_2023': 145440500, 'Exports': 465432, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec40'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Brazil', 'Forecast': 2188419.0, 'GDP_Year': '2024', 'Estimate': '2,173,666', 'GDP_Year.1': '2023', 'Estimate.1': '1,920,095', 'GDP_Year.2': '2022', 'Population_2023': 211140729, 'Exports': 389625, 'Top_Export': 'Iron ore'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec41'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Vietnam', 'Forecast': 468485.0, 'GDP_Year': '2024', 'Estimate': '429,717', 'GDP_Year.1': '2023', 'Estimate.1': '408,802', 'GDP_Year.2': '2022', 'Population_2023': 100352192, 'Exports': 374265, 'Top_Export': 'Broadcasting equipment'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec42'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Saudi Arabia', 'Forecast': 1100706.0, 'GDP_Year': '2024', 'Estimate': '1,067,583', 'GDP_Year.1': '2023', 'Estimate.1': '1,108,148', 'GDP_Year.2': '2022', 'Population_2023': 32264292, 'Exports': 370973, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec43'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Malaysia', 'Forecast': 439748.0, 'GDP_Year': '2024', 'Estimate': '399,649', 'GDP_Year.1': '2023', 'Estimate.1': '406,305', 'GDP_Year.2': '2022', 'Population_2023': 35126298, 'Exports': 352500, 'Top_Export': 'Integrated circuits'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec44'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Thailand', 'Forecast': 528919.0, 'GDP_Year': '2024', 'Estimate': '514,945', 'GDP_Year.1': '2023', 'Estimate.1': '495,340', 'GDP_Year.2': '2022', 'Population_2023': 71702435, 'Exports': 336871, 'Top_Export': 'Data processing equipment'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec45'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Indonesia', 'Forecast': 1402590.0, 'GDP_Year': '2024', 'Estimate': '1,371,171', 'GDP_Year.1': '2023', 'Estimate.1': '1,319,100', 'GDP_Year.2': '2022', 'Population_2023': 281190067, 'Exports': 315924, 'Top_Export': 'Coal'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec46'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Sweden', 'Forecast': 609039.0, 'GDP_Year': '2024', 'Estimate': '593,268', 'GDP_Year.1': '2023', 'Estimate.1': '591,188', 'GDP_Year.2': '2022', 'Population_2023': 10551494, 'Exports': 310493, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec47'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Denmark', 'Forecast': 412293.0, 'GDP_Year': '2024', 'Estimate': '404,199', 'GDP_Year.1': '2023', 'Estimate.1': '400,167', 'GDP_Year.2': '2022', 'Population_2023': 5948136, 'Exports': 273868, 'Top_Export': 'Packaged medications'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec48'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Austria', 'Forecast': 535804.0, 'GDP_Year': '2024', 'Estimate': '516,034', 'GDP_Year.1': '2023', 'Estimate.1': '470,302', 'GDP_Year.2': '2022', 'Population_2023': 9130429, 'Exports': 268277, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec49'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Turkey', 'Forecast': 1344318.0, 'GDP_Year': '2024', 'Estimate': '1,108,022', 'GDP_Year.1': '2023', 'Estimate.1': '907,118', 'GDP_Year.2': '2022', 'Population_2023': 87270501, 'Exports': 255800, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec4a'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Israel', 'Forecast': 528067.0, 'GDP_Year': '2024', 'Estimate': '509,902', 'GDP_Year.1': '2023', 'Estimate.1': '525,002', 'GDP_Year.2': '2022', 'Population_2023': 9256314, 'Exports': 166098, 'Top_Export': 'Diamonds'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec4b'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Luxembourg', 'Forecast': 91210.0, 'GDP_Year': '2024', 'Estimate': '85,755', 'GDP_Year.1': '2023', 'Estimate.1': '81,530', 'GDP_Year.2': '2022', 'Population_2023': 665098, 'Exports': 163585, 'Top_Export': 'Iron'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec4c'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Qatar', 'Forecast': 221406.0, 'GDP_Year': '2024', 'Estimate': '235,770', 'GDP_Year.1': '2022', 'Estimate.1': '237,101', 'GDP_Year.2': '2022', 'Population_2023': 2979082, 'Exports': 161693, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec4d'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Hungary', 'Forecast': 228806.0, 'GDP_Year': '2024', 'Estimate': '212,389', 'GDP_Year.1': '2023', 'Estimate.1': '177,337', 'GDP_Year.2': '2022', 'Population_2023': 9686463, 'Exports': 161609, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec4e'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Romania', 'Forecast': 380561.0, 'GDP_Year': '2024', 'Estimate': '351,003', 'GDP_Year.1': '2023', 'Estimate.1': '300,690', 'GDP_Year.2': '2022', 'Population_2023': 19118479, 'Exports': 137345, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec4f'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'South Africa', 'Forecast': 403045.0, 'GDP_Year': '2024', 'Estimate': '377,782', 'GDP_Year.1': '2023', 'Estimate.1': '405,270', 'GDP_Year.2': '2022', 'Population_2023': 63212384, 'Exports': 135951, 'Top_Export': 'Platinum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec50'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Slovakia', 'Forecast': 142617.0, 'GDP_Year': '2024', 'Estimate': '132,794', 'GDP_Year.1': '2023', 'Estimate.1': '115,304', 'GDP_Year.2': '2022', 'Population_2023': 5518055, 'Exports': 114157, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec51'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Chile', 'Forecast': 328720.0, 'GDP_Year': '2024', 'Estimate': '335,533', 'GDP_Year.1': '2023', 'Estimate.1': '300,686', 'GDP_Year.2': '2022', 'Population_2023': 19658835, 'Exports': 107077, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec52'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Greece', 'Forecast': 252732.0, 'GDP_Year': '2024', 'Estimate': '238,206', 'GDP_Year.1': '2023', 'Estimate.1': '217,285', 'GDP_Year.2': '2022', 'Population_2023': 10242908, 'Exports': 105756, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec53'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Argentina', 'Forecast': 604382.0, 'GDP_Year': '2024', 'Estimate': '640,591', 'GDP_Year.1': '2023', 'Estimate.1': '631,133', 'GDP_Year.2': '2022', 'Population_2023': 45538401, 'Exports': 102947, 'Top_Export': 'Soybeans'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec54'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Kuwait', 'Forecast': 161822.0, 'GDP_Year': '2024', 'Estimate': '161,772', 'GDP_Year.1': '2023', 'Estimate.1': '175,363', 'GDP_Year.2': '2022', 'Population_2023': 4838782, 'Exports': 101925, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec55'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Philippines', 'Forecast': 470062.0, 'GDP_Year': '2024', 'Estimate': '437,146', 'GDP_Year.1': '2023', 'Estimate.1': '404,284', 'GDP_Year.2': '2022', 'Population_2023': 114891199, 'Exports': 98518, 'Top_Export': 'Integrated circuits'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec56'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Kazakhstan', 'Forecast': 292553.0, 'GDP_Year': '2024', 'Estimate': '261,421', 'GDP_Year.1': '2023', 'Estimate.1': '225,496', 'GDP_Year.2': '2022', 'Population_2023': 20330104, 'Exports': 94052, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec57'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Iraq', 'Forecast': 264149.0, 'GDP_Year': '2024', 'Estimate': '250,843', 'GDP_Year.1': '2023', 'Estimate.1': '264,182', 'GDP_Year.2': '2022', 'Population_2023': 45074049, 'Exports': 78260, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec58'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Iran', 'Forecast': 434243.0, 'GDP_Year': '2024', 'Estimate': '401,505', 'GDP_Year.1': '2023', 'Estimate.1': '398,047', 'GDP_Year.2': '2022', 'Population_2023': 90608707, 'Exports': 76917, 'Top_Export': 'Plastic'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec59'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Egypt', 'Forecast': 380044.0, 'GDP_Year': '2024', 'Estimate': '395,926', 'GDP_Year.1': '2023', 'Estimate.1': '409,306', 'GDP_Year.2': '2022', 'Population_2023': 114535772, 'Exports': 76295, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec5a'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Colombia', 'Forecast': 417207.0, 'GDP_Year': '2024', 'Estimate': '363,540', 'GDP_Year.1': '2023', 'Estimate.1': '343,939', 'GDP_Year.2': '2022', 'Population_2023': 52321152, 'Exports': 72497, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec5b'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Peru', 'Forecast': 283309.0, 'GDP_Year': '2024', 'Estimate': '267,603', 'GDP_Year.1': '2023', 'Estimate.1': '242,631', 'GDP_Year.2': '2022', 'Population_2023': 33845617, 'Exports': 71197, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec5c'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Nigeria', 'Forecast': 199721.0, 'GDP_Year': '2024', 'Estimate': '362,815', 'GDP_Year.1': '2023', 'Estimate.1': '475,058', 'GDP_Year.2': '2022', 'Population_2023': 227882945, 'Exports': 69091, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec5d'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Algeria', 'Forecast': 260134.0, 'GDP_Year': '2024', 'Estimate': '239,899', 'GDP_Year.1': '2023', 'Estimate.1': '191,912', 'GDP_Year.2': '2022', 'Population_2023': 46164219, 'Exports': 68664, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec5e'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Lithuania', 'Forecast': 82789.0, 'GDP_Year': '2024', 'Estimate': '77,836', 'GDP_Year.1': '2023', 'Estimate.1': '70,878', 'GDP_Year.2': '2022', 'Population_2023': 2854099, 'Exports': 61386, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec5f'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Bulgaria', 'Forecast': 108425.0, 'GDP_Year': '2024', 'Estimate': '101,584', 'GDP_Year.1': '2023', 'Estimate.1': '90,213', 'GDP_Year.2': '2022', 'Population_2023': 6795803, 'Exports': 60712, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec60'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Bangladesh', 'Forecast': 451468.0, 'GDP_Year': '2024', 'Estimate': '437,415', 'GDP_Year.1': '2023', 'Estimate.1': '432,677', 'GDP_Year.2': '2022', 'Population_2023': 171466990, 'Exports': 60138, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec61'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Morocco', 'Forecast': 157087.0, 'GDP_Year': '2024', 'Estimate': '141,109', 'GDP_Year.1': '2023', 'Estimate.1': '130,912', 'GDP_Year.2': '2022', 'Population_2023': 37712505, 'Exports': 58556, 'Top_Export': 'Fertilizers'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec62'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'New Zealand', 'Forecast': 252236.0, 'GDP_Year': '2024', 'Estimate': '253,466', 'GDP_Year.1': '2023', 'Estimate.1': '245,845', 'GDP_Year.2': '2022', 'Population_2023': 5172836, 'Exports': 57462, 'Top_Export': 'Milk'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec63'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Slovenia', 'Forecast': 73198.0, 'GDP_Year': '2024', 'Estimate': '68,217', 'GDP_Year.1': '2023', 'Estimate.1': '59,981', 'GDP_Year.2': '2022', 'Population_2023': 2118396, 'Exports': 56400, 'Top_Export': 'Packaged medications'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec64'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Angola', 'Forecast': 113286.0, 'GDP_Year': '2024', 'Estimate': '84,773', 'GDP_Year.1': '2023', 'Estimate.1': '113,304', 'GDP_Year.2': '2022', 'Population_2023': 36749906, 'Exports': 50120, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec65'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Azerbaijan', 'Forecast': 75649.0, 'GDP_Year': '2024', 'Estimate': '72,356', 'GDP_Year.1': '2023', 'Estimate.1': '78,721', 'GDP_Year.2': '2022', 'Population_2023': 10318207, 'Exports': 47274, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec66'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Belarus', 'Forecast': 73129.0, 'GDP_Year': '2024', 'Estimate': '71,857', 'GDP_Year.1': '2023', 'Estimate.1': '72,873', 'GDP_Year.2': '2022', 'Population_2023': 9115680, 'Exports': 46767, 'Top_Export': 'Fertilizers'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec67'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Oman', 'Forecast': 109993.0, 'GDP_Year': '2024', 'Estimate': '108,192', 'GDP_Year.1': '2023', 'Estimate.1': '114,666', 'GDP_Year.2': '2022', 'Population_2023': 5049269, 'Exports': 46324, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec68'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Croatia', 'Forecast': 89665.0, 'GDP_Year': '2024', 'Estimate': '82,689', 'GDP_Year.1': '2023', 'Estimate.1': '71,552', 'GDP_Year.2': '2022', 'Population_2023': 3896023, 'Exports': 41952, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec69'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Pakistan', 'Forecast': 374595.0, 'GDP_Year': '2024', 'Estimate': '338,368', 'GDP_Year.1': '2023', 'Estimate.1': '326,796', 'GDP_Year.2': '2022', 'Population_2023': 247504495, 'Exports': 38700, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec6a'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Ecuador', 'Forecast': 121425.0, 'GDP_Year': '2024', 'Estimate': '118,845', 'GDP_Year.1': '2023', 'Estimate.1': '115,049', 'GDP_Year.2': '2022', 'Population_2023': 17980083, 'Exports': 36338, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec6b'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Estonia', 'Forecast': 43044.0, 'GDP_Year': '2024', 'Estimate': '40,745', 'GDP_Year.1': '2023', 'Estimate.1': '38,049', 'GDP_Year.2': '2022', 'Population_2023': 1367196, 'Exports': 32511, 'Top_Export': 'Wood'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec6c'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Bahrain', 'Forecast': 47812.0, 'GDP_Year': '2024', 'Estimate': '43,205', 'GDP_Year.1': '2023', 'Estimate.1': '44,382', 'GDP_Year.2': '2022', 'Population_2023': 1569666, 'Exports': 30097, 'Top_Export': 'Aluminium'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec6d'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Latvia', 'Forecast': 45521.0, 'GDP_Year': '2024', 'Estimate': '43,627', 'GDP_Year.1': '2023', 'Estimate.1': '40,876', 'GDP_Year.2': '2022', 'Population_2023': 1882396, 'Exports': 28854, 'Top_Export': 'Wood'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec6e'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Venezuela', 'Forecast': 106327.0, 'GDP_Year': '2024', 'Estimate': '—', 'GDP_Year.1': nan, 'Estimate.1': '129,313', 'GDP_Year.2': '2022', 'Population_2023': 28300854, 'Exports': 28684, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec6f'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Costa Rica', 'Forecast': 95149.0, 'GDP_Year': '2024', 'Estimate': '86,498', 'GDP_Year.1': '2023', 'Estimate.1': '68,380', 'GDP_Year.2': '2022', 'Population_2023': 5105525, 'Exports': 28092, 'Top_Export': 'Medical instruments'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec70'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Panama', 'Forecast': 87347.0, 'GDP_Year': '2024', 'Estimate': '83,382', 'GDP_Year.1': '2023', 'Estimate.1': '76,522', 'GDP_Year.2': '2022', 'Population_2023': 4458759, 'Exports': 27338, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec71'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Cambodia', 'Forecast': 47147.0, 'GDP_Year': '2024', 'Estimate': '31,773', 'GDP_Year.1': '2023', 'Estimate.1': '29,504', 'GDP_Year.2': '2022', 'Population_2023': 17423880, 'Exports': 25497, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec72'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Malta', 'Forecast': 22737.0, 'GDP_Year': '2024', 'Estimate': '20,957', 'GDP_Year.1': '2023', 'Estimate.1': '18,100', 'GDP_Year.2': '2022', 'Population_2023': 532956, 'Exports': 25417, 'Top_Export': 'Integrated circuits'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec73'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Dominican Republic', 'Forecast': 126238.0, 'GDP_Year': '2024', 'Estimate': '121,444', 'GDP_Year.1': '2023', 'Estimate.1': '113,537', 'GDP_Year.2': '2022', 'Population_2023': 11331265, 'Exports': 25102, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec74'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Ghana', 'Forecast': 75307.0, 'GDP_Year': '2024', 'Estimate': '76,370', 'GDP_Year.1': '2023', 'Estimate.1': '73,766', 'GDP_Year.2': '2022', 'Population_2023': 33787914, 'Exports': 23901, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec75'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Uruguay', 'Forecast': 82605.0, 'GDP_Year': '2024', 'Estimate': '77,241', 'GDP_Year.1': '2023', 'Estimate.1': '71,171', 'GDP_Year.2': '2022', 'Population_2023': 3388081, 'Exports': 22605, 'Top_Export': 'Beef'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec76'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Uzbekistan', 'Forecast': 112653.0, 'GDP_Year': '2024', 'Estimate': '90,889', 'GDP_Year.1': '2023', 'Estimate.1': '80,391', 'GDP_Year.2': '2022', 'Population_2023': 35652307, 'Exports': 21926, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec77'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Tunisia', 'Forecast': 52636.0, 'GDP_Year': '2024', 'Estimate': '48,530', 'GDP_Year.1': '2023', 'Estimate.1': '46,181', 'GDP_Year.2': '2022', 'Population_2023': 12200431, 'Exports': 19743, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec78'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Syria', 'Forecast': nan, 'GDP_Year': nan, 'Estimate': '8,980', 'GDP_Year.1': '2021', 'Estimate.1': '18,595', 'GDP_Year.2': '2022', 'Population_2023': 23594623, 'Exports': 19605, 'Top_Export': 'Olive oil'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec79'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Myanmar', 'Forecast': 64284.0, 'GDP_Year': '2024', 'Estimate': '64,815', 'GDP_Year.1': '2023', 'Estimate.1': '65,211', 'GDP_Year.2': '2022', 'Population_2023': 54133798, 'Exports': 17523, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec7a'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Guatemala', 'Forecast': 112369.0, 'GDP_Year': '2024', 'Estimate': '102,050', 'GDP_Year.1': '2023', 'Estimate.1': '95,003', 'GDP_Year.2': '2022', 'Population_2023': 18124838, 'Exports': 15318, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec7b'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Paraguay', 'Forecast': 44937.0, 'GDP_Year': '2024', 'Estimate': '42,956', 'GDP_Year.1': '2023', 'Estimate.1': '41,722', 'GDP_Year.2': '2022', 'Population_2023': 6844146, 'Exports': 14970, 'Top_Export': 'Soybeans'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec7c'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Bolivia', 'Forecast': 48172.0, 'GDP_Year': '2024', 'Estimate': '45,850', 'GDP_Year.1': '2023', 'Estimate.1': '44,008', 'GDP_Year.2': '2022', 'Population_2023': 12244159, 'Exports': 14468, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec7d'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Jordan', 'Forecast': 53305.0, 'GDP_Year': '2024', 'Estimate': '50,814', 'GDP_Year.1': '2023', 'Estimate.1': '47,452', 'GDP_Year.2': '2022', 'Population_2023': 11439213, 'Exports': 13864, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec7e'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Sri Lanka', 'Forecast': 74846.0, 'GDP_Year': '2022', 'Estimate': '84,357', 'GDP_Year.1': '2023', 'Estimate.1': '76,187', 'GDP_Year.2': '2022', 'Population_2023': 22971617, 'Exports': 13082, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec7f'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Iceland', 'Forecast': 32919.0, 'GDP_Year': '2024', 'Estimate': '31,020', 'GDP_Year.1': '2023', 'Estimate.1': '28,064', 'GDP_Year.2': '2022', 'Population_2023': 387558, 'Exports': 12867, 'Top_Export': 'Aluminium'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec80'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Zambia', 'Forecast': 29872.0, 'GDP_Year': '2024', 'Estimate': '28,163', 'GDP_Year.1': '2023', 'Estimate.1': '29,136', 'GDP_Year.2': '2022', 'Population_2023': 20723965, 'Exports': 12437, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec81'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Kenya', 'Forecast': 116321.0, 'GDP_Year': '2024', 'Estimate': '107,441', 'GDP_Year.1': '2023', 'Estimate.1': '113,419', 'GDP_Year.2': '2022', 'Population_2023': 55339003, 'Exports': 11825, 'Top_Export': 'Tea'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec82'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Papua New Guinea', 'Forecast': 31716.0, 'GDP_Year': '2024', 'Estimate': '30,933', 'GDP_Year.1': '2022', 'Estimate.1': '31,609', 'GDP_Year.2': '2022', 'Population_2023': 10389635, 'Exports': 11624, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec83'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Bosnia and Herzegovina', 'Forecast': 29078.0, 'GDP_Year': '2024', 'Estimate': '27,055', 'GDP_Year.1': '2023', 'Estimate.1': '24,473', 'GDP_Year.2': '2022', 'Population_2023': 3185073, 'Exports': 11523, 'Top_Export': 'Energy'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec84'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Trinidad and Tobago', 'Forecast': 28365.0, 'GDP_Year': '2024', 'Estimate': '28,140', 'GDP_Year.1': '2023', 'Estimate.1': '30,053', 'GDP_Year.2': '2022', 'Population_2023': 1502932, 'Exports': 11467, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec85'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Brunei', 'Forecast': 15510.0, 'GDP_Year': '2024', 'Estimate': '15,128', 'GDP_Year.1': '2023', 'Estimate.1': '16,681', 'GDP_Year.2': '2022', 'Population_2023': 458949, 'Exports': 11202, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec86'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Mongolia', 'Forecast': 21943.0, 'GDP_Year': '2024', 'Estimate': '19,872', 'GDP_Year.1': '2023', 'Estimate.1': '17,146', 'GDP_Year.2': '2022', 'Population_2023': 3431932, 'Exports': 10989, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec87'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Guinea', 'Forecast': 25447.0, 'GDP_Year': '2024', 'Estimate': '23,612', 'GDP_Year.1': '2023', 'Estimate.1': '20,846', 'GDP_Year.2': '2022', 'Population_2023': 14405465, 'Exports': 10265, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec88'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'North Macedonia', 'Forecast': 15873.0, 'GDP_Year': '2024', 'Estimate': '14,761', 'GDP_Year.1': '2023', 'Estimate.1': '13,711', 'GDP_Year.2': '2022', 'Population_2023': 1831802, 'Exports': 10150, 'Top_Export': 'Automobile catalysts'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec89'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Lebanon', 'Forecast': 21780.0, 'GDP_Year': '2022', 'Estimate': '17,937', 'GDP_Year.1': '2023', 'Estimate.1': '39,303', 'GDP_Year.2': '2022', 'Population_2023': 5733493, 'Exports': 10146, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec8a'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'El Salvador', 'Forecast': 35848.0, 'GDP_Year': '2024', 'Estimate': '34,016', 'GDP_Year.1': '2023', 'Estimate.1': '32,488', 'GDP_Year.2': '2022', 'Population_2023': 6309624, 'Exports': 10129, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec8b'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Armenia', 'Forecast': 25408.0, 'GDP_Year': '2024', 'Estimate': '24,212', 'GDP_Year.1': '2023', 'Estimate.1': '19,513', 'GDP_Year.2': '2022', 'Population_2023': 2943393, 'Exports': 9699, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec8c'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Libya', 'Forecast': 44812.0, 'GDP_Year': '2024', 'Estimate': '50,492', 'GDP_Year.1': '2023', 'Estimate.1': '40,537', 'GDP_Year.2': '2022', 'Population_2023': 7305659, 'Exports': 9537, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec8d'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Ethiopia', 'Forecast': 145031.0, 'GDP_Year': '2024', 'Estimate': '163,698', 'GDP_Year.1': '2023', 'Estimate.1': '118,971', 'GDP_Year.2': '2022', 'Population_2023': 128691692, 'Exports': 9496, 'Top_Export': 'Coffee'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec8e'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Mozambique', 'Forecast': 22975.0, 'GDP_Year': '2024', 'Estimate': '20,625', 'GDP_Year.1': '2023', 'Estimate.1': '18,406', 'GDP_Year.2': '2022', 'Population_2023': 33635160, 'Exports': 9409, 'Top_Export': 'Coal'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec8f'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Honduras', 'Forecast': 36735.0, 'GDP_Year': '2024', 'Estimate': '34,401', 'GDP_Year.1': '2023', 'Estimate.1': '31,717', 'GDP_Year.2': '2022', 'Population_2023': 10644851, 'Exports': 9243, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec90'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Cuba', 'Forecast': nan, 'GDP_Year': nan, 'Estimate': '—', 'GDP_Year.1': nan, 'Estimate.1': '147,193', 'GDP_Year.2': '2022', 'Population_2023': 11019931, 'Exports': 8769, 'Top_Export': 'Cigars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec91'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Turkmenistan', 'Forecast': 83883.0, 'GDP_Year': '2024', 'Estimate': '59,887', 'GDP_Year.1': '2023', 'Estimate.1': '67,009', 'GDP_Year.2': '2022', 'Population_2023': 7364438, 'Exports': 8164, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec92'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Botswana', 'Forecast': 21418.0, 'GDP_Year': '2024', 'Estimate': '19,396', 'GDP_Year.1': '2023', 'Estimate.1': '20,352', 'GDP_Year.2': '2022', 'Population_2023': 2480244, 'Exports': 7930, 'Top_Export': 'Diamonds'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec93'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Nicaragua', 'Forecast': 18829.0, 'GDP_Year': '2024', 'Estimate': '17,829', 'GDP_Year.1': '2023', 'Estimate.1': '15,671', 'GDP_Year.2': '2022', 'Population_2023': 6823613, 'Exports': 7870, 'Top_Export': 'Clothing'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec94'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Laos', 'Forecast': 15190.0, 'GDP_Year': '2024', 'Estimate': '15,843', 'GDP_Year.1': '2023', 'Estimate.1': '15,362', 'GDP_Year.2': '2022', 'Population_2023': 7664993, 'Exports': 7819, 'Top_Export': 'Energy'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec95'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Cameroon', 'Forecast': 53391.0, 'GDP_Year': '2024', 'Estimate': '47,946', 'GDP_Year.1': '2023', 'Estimate.1': '44,341', 'GDP_Year.2': '2022', 'Population_2023': 28372687, 'Exports': 7449, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec96'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Albania', 'Forecast': 25431.0, 'GDP_Year': '2024', 'Estimate': '22,978', 'GDP_Year.1': '2023', 'Estimate.1': '18,916', 'GDP_Year.2': '2022', 'Population_2023': 2811655, 'Exports': 7057, 'Top_Export': 'Footwear'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec97'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Equatorial Guinea', 'Forecast': 10708.0, 'GDP_Year': '2024', 'Estimate': '12,117', 'GDP_Year.1': '2023', 'Estimate.1': '11,767', 'GDP_Year.2': '2022', 'Population_2023': 1847549, 'Exports': 6656, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec98'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Chad', 'Forecast': 18697.0, 'GDP_Year': '2024', 'Estimate': '13,149', 'GDP_Year.1': '2023', 'Estimate.1': '16,799', 'GDP_Year.2': '2022', 'Population_2023': 19319064, 'Exports': 6503, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec99'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Jamaica', 'Forecast': 20098.0, 'GDP_Year': '2024', 'Estimate': '19,423', 'GDP_Year.1': '2023', 'Estimate.1': '17,097', 'GDP_Year.2': '2022', 'Population_2023': 2839786, 'Exports': 6424, 'Top_Export': 'Aluminium oxide'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec9a'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Burkina Faso', 'Forecast': 21902.0, 'GDP_Year': '2024', 'Estimate': '20,325', 'GDP_Year.1': '2023', 'Estimate.1': '19,176', 'GDP_Year.2': '2022', 'Population_2023': 23025776, 'Exports': 6233, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec9b'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Uganda', 'Forecast': 55587.0, 'GDP_Year': '2024', 'Estimate': '49,273', 'GDP_Year.1': '2023', 'Estimate.1': '48,243', 'GDP_Year.2': '2022', 'Population_2023': 48656601, 'Exports': 6177, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec9c'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Sudan', 'Forecast': 26865.0, 'GDP_Year': '2024', 'Estimate': '109,327', 'GDP_Year.1': '2023', 'Estimate.1': '36,729', 'GDP_Year.2': '2022', 'Population_2023': 50042791, 'Exports': 5908, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec9d'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Gabon', 'Forecast': 21013.0, 'GDP_Year': '2024', 'Estimate': '20,516', 'GDP_Year.1': '2023', 'Estimate.1': '20,132', 'GDP_Year.2': '2022', 'Population_2023': 2484789, 'Exports': 5390, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec9e'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Mali', 'Forecast': 21662.0, 'GDP_Year': '2024', 'Estimate': '20,905', 'GDP_Year.1': '2023', 'Estimate.1': '18,827', 'GDP_Year.2': '2022', 'Population_2023': 23769127, 'Exports': 5381, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabec9f'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Senegal', 'Forecast': 33685.0, 'GDP_Year': '2024', 'Estimate': '31,014', 'GDP_Year.1': '2023', 'Estimate.1': '27,775', 'GDP_Year.2': '2022', 'Population_2023': 18077573, 'Exports': 5287, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca0'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Zimbabwe', 'Forecast': 35919.0, 'GDP_Year': '2024', 'Estimate': '26,538', 'GDP_Year.1': '2023', 'Estimate.1': '26,418', 'GDP_Year.2': '2022', 'Population_2023': 16340822, 'Exports': 5263, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca1'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Djibouti', 'Forecast': 4364.0, 'GDP_Year': '2024', 'Estimate': '4,099', 'GDP_Year.1': '2023', 'Estimate.1': '4,003', 'GDP_Year.2': '2022', 'Population_2023': 1152944, 'Exports': 5160, 'Top_Export': 'Palm oil'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca2'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Maldives', 'Forecast': 7199.0, 'GDP_Year': '2024', 'Estimate': '6,600', 'GDP_Year.1': '2023', 'Estimate.1': '6,170', 'GDP_Year.2': '2022', 'Population_2023': 525994, 'Exports': 5096, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca3'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Namibia', 'Forecast': 12765.0, 'GDP_Year': '2024', 'Estimate': '12,351', 'GDP_Year.1': '2023', 'Estimate.1': '12,607', 'GDP_Year.2': '2022', 'Population_2023': 2963095, 'Exports': 5080, 'Top_Export': 'Copper'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca4'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Mauritius', 'Forecast': 16359.0, 'GDP_Year': '2024', 'Estimate': '14,397', 'GDP_Year.1': '2023', 'Estimate.1': '12,898', 'GDP_Year.2': '2022', 'Population_2023': 1273588, 'Exports': 4918, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca5'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'South Sudan', 'Forecast': 6517.0, 'GDP_Year': '2024', 'Estimate': '—', 'GDP_Year.1': nan, 'Estimate.1': '4,616', 'GDP_Year.2': '2022', 'Population_2023': 11483374, 'Exports': 4652, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca6'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Guyana', 'Forecast': 21178.0, 'GDP_Year': '2024', 'Estimate': '16,786', 'GDP_Year.1': '2023', 'Estimate.1': '14,718', 'GDP_Year.2': '2022', 'Population_2023': 826353, 'Exports': 4640, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca7'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Benin', 'Forecast': 21371.0, 'GDP_Year': '2024', 'Estimate': '19,673', 'GDP_Year.1': '2023', 'Estimate.1': '17,396', 'GDP_Year.2': '2022', 'Population_2023': 14111034, 'Exports': 4154, 'Top_Export': 'Cotton'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca8'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'San Marino', 'Forecast': 2033.0, 'GDP_Year': '2024', 'Estimate': '1,855', 'GDP_Year.1': '2021', 'Estimate.1': '1,780', 'GDP_Year.2': '2022', 'Population_2023': 33733, 'Exports': 3420, 'Top_Export': 'Dish washing machines'}
# {'_id': ObjectId('6764ed542cdfb9c98fabeca9'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Madagascar', 'Forecast': 16465.0, 'GDP_Year': '2024', 'Estimate': '16,032', 'GDP_Year.1': '2023', 'Estimate.1': '14,954', 'GDP_Year.2': '2022', 'Population_2023': 31195932, 'Exports': 3341, 'Top_Export': 'Vanilla'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecaa'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Kyrgyzstan', 'Forecast': 15770.0, 'GDP_Year': '2024', 'Estimate': '13,782', 'GDP_Year.1': '2023', 'Estimate.1': '12,560', 'GDP_Year.2': '2022', 'Population_2023': 7073516, 'Exports': 3292, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecab'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Bahamas', 'Forecast': 14390.0, 'GDP_Year': '2024', 'Estimate': '14,339', 'GDP_Year.1': '2023', 'Estimate.1': '12,897', 'GDP_Year.2': '2022', 'Population_2023': 399440, 'Exports': 3202, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecac'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Mauritania', 'Forecast': 10628.0, 'GDP_Year': '2024', 'Estimate': '10,453', 'GDP_Year.1': '2023', 'Estimate.1': '10,997', 'GDP_Year.2': '2022', 'Population_2023': 5022441, 'Exports': 3181, 'Top_Export': 'Iron ore'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecad'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Montenegro', 'Forecast': 8010.0, 'GDP_Year': '2024', 'Estimate': '7,405', 'GDP_Year.1': '2023', 'Estimate.1': '6,229', 'GDP_Year.2': '2022', 'Population_2023': 633552, 'Exports': 3178, 'Top_Export': 'Aluminium'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecae'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Rwanda', 'Forecast': 13701.0, 'GDP_Year': '2024', 'Estimate': '14,098', 'GDP_Year.1': '2023', 'Estimate.1': '13,312', 'GDP_Year.2': '2022', 'Population_2023': 13954471, 'Exports': 2994, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecaf'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Nepal', 'Forecast': 43673.0, 'GDP_Year': '2024', 'Estimate': '40,908', 'GDP_Year.1': '2023', 'Estimate.1': '39,406', 'GDP_Year.2': '2022', 'Population_2023': 29964614, 'Exports': 2722, 'Top_Export': 'Soybean oil'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb0'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Suriname', 'Forecast': 4337.0, 'GDP_Year': '2024', 'Estimate': '3,782', 'GDP_Year.1': '2023', 'Estimate.1': '3,620', 'GDP_Year.2': '2022', 'Population_2023': 628886, 'Exports': 2599, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb1'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Andorra', 'Forecast': 3897.0, 'GDP_Year': '2024', 'Estimate': '3,728', 'GDP_Year.1': '2023', 'Estimate.1': '3,376', 'GDP_Year.2': '2022', 'Population_2023': 80856, 'Exports': 2414, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb2'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Fiji', 'Forecast': 5801.0, 'GDP_Year': '2024', 'Estimate': '5,495', 'GDP_Year.1': '2023', 'Estimate.1': '4,979', 'GDP_Year.2': '2022', 'Population_2023': 924145, 'Exports': 2376, 'Top_Export': 'Water'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb3'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Barbados', 'Forecast': 6863.0, 'GDP_Year': '2024', 'Estimate': '6,394', 'GDP_Year.1': '2023', 'Estimate.1': '5,699', 'GDP_Year.2': '2022', 'Population_2023': 282336, 'Exports': 2228, 'Top_Export': 'Rum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb4'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Eswatini', 'Forecast': 5085.0, 'GDP_Year': '2024', 'Estimate': '4,598', 'GDP_Year.1': '2023', 'Estimate.1': '4,326', 'GDP_Year.2': '2022', 'Population_2023': 1230506, 'Exports': 2131, 'Top_Export': 'Soft drink concentrates'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb5'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Tajikistan', 'Forecast': 13000.0, 'GDP_Year': '2024', 'Estimate': '12,061', 'GDP_Year.1': '2023', 'Estimate.1': '10,492', 'GDP_Year.2': '2022', 'Population_2023': 10389799, 'Exports': 1753, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb6'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Seychelles', 'Forecast': 2203.0, 'GDP_Year': '2024', 'Estimate': '2,141', 'GDP_Year.1': '2023', 'Estimate.1': '1,994', 'GDP_Year.2': '2022', 'Population_2023': 127951, 'Exports': 1751, 'Top_Export': 'Boats'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb7'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Togo', 'Forecast': 9832.0, 'GDP_Year': '2024', 'Estimate': '9,171', 'GDP_Year.1': '2023', 'Estimate.1': '8,087', 'GDP_Year.2': '2022', 'Population_2023': 9304337, 'Exports': 1721, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb8'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Malawi', 'Forecast': 11241.0, 'GDP_Year': '2024', 'Estimate': '14,084', 'GDP_Year.1': '2023', 'Estimate.1': '12,558', 'GDP_Year.2': '2022', 'Population_2023': 21104482, 'Exports': 1538, 'Top_Export': 'Tobacco'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecb9'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Niger', 'Forecast': 18816.0, 'GDP_Year': '2024', 'Estimate': '16,819', 'GDP_Year.1': '2023', 'Estimate.1': '15,414', 'GDP_Year.2': '2022', 'Population_2023': 26159867, 'Exports': 1487, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecba'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Afghanistan', 'Forecast': 14467.0, 'GDP_Year': '2022', 'Estimate': '14,502', 'GDP_Year.1': '2022', 'Estimate.1': '14,174', 'GDP_Year.2': '2022', 'Population_2023': 41454761, 'Exports': 1476, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecbb'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Belize', 'Forecast': 3296.0, 'GDP_Year': '2024', 'Estimate': '3,282', 'GDP_Year.1': '2023', 'Estimate.1': '2,830', 'GDP_Year.2': '2022', 'Population_2023': 411106, 'Exports': 1345, 'Top_Export': 'Sugarcane'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecbc'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Haiti', 'Forecast': 24046.0, 'GDP_Year': '2024', 'Estimate': '19,851', 'GDP_Year.1': '2023', 'Estimate.1': '18,751', 'GDP_Year.2': '2022', 'Population_2023': 11637398, 'Exports': 1241, 'Top_Export': 'Clothes'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecbd'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Sierra Leone', 'Forecast': 4558.0, 'GDP_Year': '2024', 'Estimate': '3,810', 'GDP_Year.1': '2023', 'Estimate.1': '3,481', 'GDP_Year.2': '2022', 'Population_2023': 8460512, 'Exports': 1114, 'Top_Export': 'Titanium ore'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecbe'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Lesotho', 'Forecast': 2395.0, 'GDP_Year': '2024', 'Estimate': '2,046', 'GDP_Year.1': '2023', 'Estimate.1': '2,287', 'GDP_Year.2': '2022', 'Population_2023': 2311472, 'Exports': 1066, 'Top_Export': 'Diamonds'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecbf'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Yemen', 'Forecast': 16940.0, 'GDP_Year': '2024', 'Estimate': '—', 'GDP_Year.1': nan, 'Estimate.1': '11,007', 'GDP_Year.2': '2022', 'Population_2023': 39390799, 'Exports': 938, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc0'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Cape Verde', 'Forecast': 2718.0, 'GDP_Year': '2024', 'Estimate': '2,587', 'GDP_Year.1': '2023', 'Estimate.1': '2,314', 'GDP_Year.2': '2022', 'Population_2023': 522331, 'Exports': 855, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc1'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Bhutan', 'Forecast': 3110.0, 'GDP_Year': '2024', 'Estimate': '2,898', 'GDP_Year.1': '2022', 'Estimate.1': '2,898', 'GDP_Year.2': '2022', 'Population_2023': 786385, 'Exports': 791, 'Top_Export': 'Ferroalloys'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc2'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Antigua and Barbuda', 'Forecast': 2127.0, 'GDP_Year': '2024', 'Estimate': '2,033', 'GDP_Year.1': '2023', 'Estimate.1': '1,770', 'GDP_Year.2': '2022', 'Population_2023': 93316, 'Exports': 752, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc3'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Saint Lucia', 'Forecast': 2582.0, 'GDP_Year': '2024', 'Estimate': '2,520', 'GDP_Year.1': '2023', 'Estimate.1': '2,165', 'GDP_Year.2': '2022', 'Population_2023': 179285, 'Exports': 711, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc4'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Liberia', 'Forecast': 4754.0, 'GDP_Year': '2024', 'Estimate': '4,332', 'GDP_Year.1': '2023', 'Estimate.1': '3,265', 'GDP_Year.2': '2022', 'Population_2023': 5493031, 'Exports': 554, 'Top_Export': 'Iron ore'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc5'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Solomon Islands', 'Forecast': 1707.0, 'GDP_Year': '2024', 'Estimate': '1,631', 'GDP_Year.1': '2023', 'Estimate.1': '1,597', 'GDP_Year.2': '2022', 'Population_2023': 800005, 'Exports': 411, 'Top_Export': 'Wood'}
# {'_id': ObjectId('6764ed542cdfb9c98fabecc6'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Grenada', 'Forecast': 1406.0, 'GDP_Year': '2024', 'Estimate': '1,320', 'GDP_Year.1': '2023', 'Estimate.1': '1,192', 'GDP_Year.2': '2022', 'Population_2023': 117081, 'Exports': 394, 'Top_Export': 'Fish'}
# ...
# {'_id': ObjectId('6764eda12cdfb9c98fabedfd'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Benin', 'Forecast': 21371.0, 'GDP_Year': '2024', 'Estimate': '19,673', 'GDP_Year.1': '2023', 'Estimate.1': '17,396', 'GDP_Year.2': '2022', 'Population_2023': 14111034, 'Exports': 4154, 'Top_Export': 'Cotton'}
# {'_id': ObjectId('6764eda12cdfb9c98fabedfe'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'San Marino', 'Forecast': 2033.0, 'GDP_Year': '2024', 'Estimate': '1,855', 'GDP_Year.1': '2021', 'Estimate.1': '1,780', 'GDP_Year.2': '2022', 'Population_2023': 33733, 'Exports': 3420, 'Top_Export': 'Dish washing machines'}
# {'_id': ObjectId('6764eda12cdfb9c98fabedff'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Madagascar', 'Forecast': 16465.0, 'GDP_Year': '2024', 'Estimate': '16,032', 'GDP_Year.1': '2023', 'Estimate.1': '14,954', 'GDP_Year.2': '2022', 'Population_2023': 31195932, 'Exports': 3341, 'Top_Export': 'Vanilla'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee00'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Kyrgyzstan', 'Forecast': 15770.0, 'GDP_Year': '2024', 'Estimate': '13,782', 'GDP_Year.1': '2023', 'Estimate.1': '12,560', 'GDP_Year.2': '2022', 'Population_2023': 7073516, 'Exports': 3292, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee01'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Bahamas', 'Forecast': 14390.0, 'GDP_Year': '2024', 'Estimate': '14,339', 'GDP_Year.1': '2023', 'Estimate.1': '12,897', 'GDP_Year.2': '2022', 'Population_2023': 399440, 'Exports': 3202, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee02'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Mauritania', 'Forecast': 10628.0, 'GDP_Year': '2024', 'Estimate': '10,453', 'GDP_Year.1': '2023', 'Estimate.1': '10,997', 'GDP_Year.2': '2022', 'Population_2023': 5022441, 'Exports': 3181, 'Top_Export': 'Iron ore'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee03'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Montenegro', 'Forecast': 8010.0, 'GDP_Year': '2024', 'Estimate': '7,405', 'GDP_Year.1': '2023', 'Estimate.1': '6,229', 'GDP_Year.2': '2022', 'Population_2023': 633552, 'Exports': 3178, 'Top_Export': 'Aluminium'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee04'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Rwanda', 'Forecast': 13701.0, 'GDP_Year': '2024', 'Estimate': '14,098', 'GDP_Year.1': '2023', 'Estimate.1': '13,312', 'GDP_Year.2': '2022', 'Population_2023': 13954471, 'Exports': 2994, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee05'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Nepal', 'Forecast': 43673.0, 'GDP_Year': '2024', 'Estimate': '40,908', 'GDP_Year.1': '2023', 'Estimate.1': '39,406', 'GDP_Year.2': '2022', 'Population_2023': 29964614, 'Exports': 2722, 'Top_Export': 'Soybean oil'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee06'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Suriname', 'Forecast': 4337.0, 'GDP_Year': '2024', 'Estimate': '3,782', 'GDP_Year.1': '2023', 'Estimate.1': '3,620', 'GDP_Year.2': '2022', 'Population_2023': 628886, 'Exports': 2599, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee07'), 'UNContinentialRegion': 'Europe', 'Country_Territory': 'Andorra', 'Forecast': 3897.0, 'GDP_Year': '2024', 'Estimate': '3,728', 'GDP_Year.1': '2023', 'Estimate.1': '3,376', 'GDP_Year.2': '2022', 'Population_2023': 80856, 'Exports': 2414, 'Top_Export': 'Cars'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee08'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Fiji', 'Forecast': 5801.0, 'GDP_Year': '2024', 'Estimate': '5,495', 'GDP_Year.1': '2023', 'Estimate.1': '4,979', 'GDP_Year.2': '2022', 'Population_2023': 924145, 'Exports': 2376, 'Top_Export': 'Water'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee09'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Barbados', 'Forecast': 6863.0, 'GDP_Year': '2024', 'Estimate': '6,394', 'GDP_Year.1': '2023', 'Estimate.1': '5,699', 'GDP_Year.2': '2022', 'Population_2023': 282336, 'Exports': 2228, 'Top_Export': 'Rum'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee0a'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Eswatini', 'Forecast': 5085.0, 'GDP_Year': '2024', 'Estimate': '4,598', 'GDP_Year.1': '2023', 'Estimate.1': '4,326', 'GDP_Year.2': '2022', 'Population_2023': 1230506, 'Exports': 2131, 'Top_Export': 'Soft drink concentrates'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee0b'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Tajikistan', 'Forecast': 13000.0, 'GDP_Year': '2024', 'Estimate': '12,061', 'GDP_Year.1': '2023', 'Estimate.1': '10,492', 'GDP_Year.2': '2022', 'Population_2023': 10389799, 'Exports': 1753, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee0c'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Seychelles', 'Forecast': 2203.0, 'GDP_Year': '2024', 'Estimate': '2,141', 'GDP_Year.1': '2023', 'Estimate.1': '1,994', 'GDP_Year.2': '2022', 'Population_2023': 127951, 'Exports': 1751, 'Top_Export': 'Boats'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee0d'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Togo', 'Forecast': 9832.0, 'GDP_Year': '2024', 'Estimate': '9,171', 'GDP_Year.1': '2023', 'Estimate.1': '8,087', 'GDP_Year.2': '2022', 'Population_2023': 9304337, 'Exports': 1721, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee0e'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Malawi', 'Forecast': 11241.0, 'GDP_Year': '2024', 'Estimate': '14,084', 'GDP_Year.1': '2023', 'Estimate.1': '12,558', 'GDP_Year.2': '2022', 'Population_2023': 21104482, 'Exports': 1538, 'Top_Export': 'Tobacco'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee0f'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Niger', 'Forecast': 18816.0, 'GDP_Year': '2024', 'Estimate': '16,819', 'GDP_Year.1': '2023', 'Estimate.1': '15,414', 'GDP_Year.2': '2022', 'Population_2023': 26159867, 'Exports': 1487, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee10'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Afghanistan', 'Forecast': 14467.0, 'GDP_Year': '2022', 'Estimate': '14,502', 'GDP_Year.1': '2022', 'Estimate.1': '14,174', 'GDP_Year.2': '2022', 'Population_2023': 41454761, 'Exports': 1476, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee11'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Belize', 'Forecast': 3296.0, 'GDP_Year': '2024', 'Estimate': '3,282', 'GDP_Year.1': '2023', 'Estimate.1': '2,830', 'GDP_Year.2': '2022', 'Population_2023': 411106, 'Exports': 1345, 'Top_Export': 'Sugarcane'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee12'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Haiti', 'Forecast': 24046.0, 'GDP_Year': '2024', 'Estimate': '19,851', 'GDP_Year.1': '2023', 'Estimate.1': '18,751', 'GDP_Year.2': '2022', 'Population_2023': 11637398, 'Exports': 1241, 'Top_Export': 'Clothes'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee13'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Sierra Leone', 'Forecast': 4558.0, 'GDP_Year': '2024', 'Estimate': '3,810', 'GDP_Year.1': '2023', 'Estimate.1': '3,481', 'GDP_Year.2': '2022', 'Population_2023': 8460512, 'Exports': 1114, 'Top_Export': 'Titanium ore'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee14'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Lesotho', 'Forecast': 2395.0, 'GDP_Year': '2024', 'Estimate': '2,046', 'GDP_Year.1': '2023', 'Estimate.1': '2,287', 'GDP_Year.2': '2022', 'Population_2023': 2311472, 'Exports': 1066, 'Top_Export': 'Diamonds'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee15'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Yemen', 'Forecast': 16940.0, 'GDP_Year': '2024', 'Estimate': '—', 'GDP_Year.1': nan, 'Estimate.1': '11,007', 'GDP_Year.2': '2022', 'Population_2023': 39390799, 'Exports': 938, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee16'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Cape Verde', 'Forecast': 2718.0, 'GDP_Year': '2024', 'Estimate': '2,587', 'GDP_Year.1': '2023', 'Estimate.1': '2,314', 'GDP_Year.2': '2022', 'Population_2023': 522331, 'Exports': 855, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee17'), 'UNContinentialRegion': 'Asia', 'Country_Territory': 'Bhutan', 'Forecast': 3110.0, 'GDP_Year': '2024', 'Estimate': '2,898', 'GDP_Year.1': '2022', 'Estimate.1': '2,898', 'GDP_Year.2': '2022', 'Population_2023': 786385, 'Exports': 791, 'Top_Export': 'Ferroalloys'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee18'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Antigua and Barbuda', 'Forecast': 2127.0, 'GDP_Year': '2024', 'Estimate': '2,033', 'GDP_Year.1': '2023', 'Estimate.1': '1,770', 'GDP_Year.2': '2022', 'Population_2023': 93316, 'Exports': 752, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee19'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Saint Lucia', 'Forecast': 2582.0, 'GDP_Year': '2024', 'Estimate': '2,520', 'GDP_Year.1': '2023', 'Estimate.1': '2,165', 'GDP_Year.2': '2022', 'Population_2023': 179285, 'Exports': 711, 'Top_Export': 'Petroleum'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee1a'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Liberia', 'Forecast': 4754.0, 'GDP_Year': '2024', 'Estimate': '4,332', 'GDP_Year.1': '2023', 'Estimate.1': '3,265', 'GDP_Year.2': '2022', 'Population_2023': 5493031, 'Exports': 554, 'Top_Export': 'Iron ore'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee1b'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Solomon Islands', 'Forecast': 1707.0, 'GDP_Year': '2024', 'Estimate': '1,631', 'GDP_Year.1': '2023', 'Estimate.1': '1,597', 'GDP_Year.2': '2022', 'Population_2023': 800005, 'Exports': 411, 'Top_Export': 'Wood'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee1c'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Grenada', 'Forecast': 1406.0, 'GDP_Year': '2024', 'Estimate': '1,320', 'GDP_Year.1': '2023', 'Estimate.1': '1,192', 'GDP_Year.2': '2022', 'Population_2023': 117081, 'Exports': 394, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee1d'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Saint Kitts and Nevis', 'Forecast': 1134.0, 'GDP_Year': '2024', 'Estimate': '1,077', 'GDP_Year.1': '2023', 'Estimate.1': '979', 'GDP_Year.2': '2022', 'Population_2023': 46758, 'Exports': 393, 'Top_Export': 'Broadcasting equipment'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee1e'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Eritrea', 'Forecast': nan, 'GDP_Year': nan, 'Estimate': '—', 'GDP_Year.1': nan, 'Estimate.1': '2,383', 'GDP_Year.2': '2022', 'Population_2023': 3470390, 'Exports': 375, 'Top_Export': 'Zinc'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee1f'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Guinea-Bissau', 'Forecast': 2151.0, 'GDP_Year': '2024', 'Estimate': '1,966', 'GDP_Year.1': '2023', 'Estimate.1': '1,574', 'GDP_Year.2': '2022', 'Population_2023': 2153339, 'Exports': 335, 'Top_Export': 'Cashews'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee20'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Central African Republic', 'Forecast': 2810.0, 'GDP_Year': '2024', 'Estimate': '2,555', 'GDP_Year.1': '2023', 'Estimate.1': '2,395', 'GDP_Year.2': '2022', 'Population_2023': 5152421, 'Exports': 316, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee21'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Burundi', 'Forecast': 3075.0, 'GDP_Year': '2024', 'Estimate': '2,642', 'GDP_Year.1': '2023', 'Estimate.1': '4,032', 'GDP_Year.2': '2022', 'Population_2023': 13689450, 'Exports': 285, 'Top_Export': 'Gold'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee22'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Samoa', 'Forecast': 1024.0, 'GDP_Year': '2024', 'Estimate': '934', 'GDP_Year.1': '2023', 'Estimate.1': '857', 'GDP_Year.2': '2022', 'Population_2023': 216663, 'Exports': 171, 'Top_Export': 'Coconut oil'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee23'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Comoros', 'Forecast': 1422.0, 'GDP_Year': '2024', 'Estimate': '1,352', 'GDP_Year.1': '2023', 'Estimate.1': '1,246', 'GDP_Year.2': '2022', 'Population_2023': 850387, 'Exports': 140, 'Top_Export': 'Cloves'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee24'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Saint Vincent and the Grenadines', 'Forecast': 1128.0, 'GDP_Year': '2024', 'Estimate': '1,066', 'GDP_Year.1': '2023', 'Estimate.1': '946', 'GDP_Year.2': '2022', 'Population_2023': 101323, 'Exports': 138, 'Top_Export': 'Boats'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee25'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'Gambia', 'Forecast': 2694.0, 'GDP_Year': '2024', 'Estimate': '2,340', 'GDP_Year.1': '2023', 'Estimate.1': '2,231', 'GDP_Year.2': '2022', 'Population_2023': 2697845, 'Exports': 135, 'Top_Export': 'Cashews'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee26'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Marshall Islands', 'Forecast': 305.0, 'GDP_Year': '2024', 'Estimate': '284', 'GDP_Year.1': '2023', 'Estimate.1': '279', 'GDP_Year.2': '2022', 'Population_2023': 38827, 'Exports': 130, 'Top_Export': 'Boats'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee27'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Micronesia', 'Forecast': 484.0, 'GDP_Year': '2024', 'Estimate': '460', 'GDP_Year.1': '2023', 'Estimate.1': '427', 'GDP_Year.2': '2022', 'Population_2023': 112630, 'Exports': 126, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee28'), 'UNContinentialRegion': 'Americas', 'Country_Territory': 'Dominica', 'Forecast': 708.0, 'GDP_Year': '2024', 'Estimate': '654', 'GDP_Year.1': '2023', 'Estimate.1': '612', 'GDP_Year.2': '2022', 'Population_2023': 66510, 'Exports': 123, 'Top_Export': 'Medical instruments'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee29'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Vanuatu', 'Forecast': 1289.0, 'GDP_Year': '2024', 'Estimate': '1,126', 'GDP_Year.1': '2023', 'Estimate.1': '985', 'GDP_Year.2': '2022', 'Population_2023': 320409, 'Exports': 89, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee2a'), 'UNContinentialRegion': 'Africa', 'Country_Territory': 'São Tomé and Príncipe', 'Forecast': 751.0, 'GDP_Year': '2024', 'Estimate': '603', 'GDP_Year.1': '2023', 'Estimate.1': '546', 'GDP_Year.2': '2022', 'Population_2023': 230871, 'Exports': 75, 'Top_Export': 'Cocoa beans'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee2b'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Tonga', 'Forecast': 581.0, 'GDP_Year': '2024', 'Estimate': '500', 'GDP_Year.1': '2022', 'Estimate.1': '488', 'GDP_Year.2': '2022', 'Population_2023': 104597, 'Exports': 60, 'Top_Export': 'Shellfish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee2c'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Nauru', 'Forecast': 161.0, 'GDP_Year': '2024', 'Estimate': '154', 'GDP_Year.1': '2023', 'Estimate.1': '147', 'GDP_Year.2': '2022', 'Population_2023': 11875, 'Exports': 31, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee2d'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Palau', 'Forecast': 308.0, 'GDP_Year': '2024', 'Estimate': '263', 'GDP_Year.1': '2023', 'Estimate.1': '225', 'GDP_Year.2': '2022', 'Population_2023': 17727, 'Exports': 12, 'Top_Export': 'Computers'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee2e'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Kiribati', 'Forecast': 311.0, 'GDP_Year': '2024', 'Estimate': '279', 'GDP_Year.1': '2023', 'Estimate.1': '223', 'GDP_Year.2': '2022', 'Population_2023': 132530, 'Exports': 11, 'Top_Export': 'Fish'}
# {'_id': ObjectId('6764eda12cdfb9c98fabee2f'), 'UNContinentialRegion': 'Oceania', 'Country_Territory': 'Tuvalu', 'Forecast': 66.0, 'GDP_Year': '2024', 'Estimate': '62', 'GDP_Year.1': '2023', 'Estimate.1': '59', 'GDP_Year.2': '2022', 'Population_2023': 9816, 'Exports': 3, 'Top_Export': 'Boats'}
